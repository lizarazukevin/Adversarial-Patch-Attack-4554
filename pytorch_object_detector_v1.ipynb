# %%
# !pwd
# Out:
# /home/mdelab/comp_vision

# %%
# Clone yolov5 repo
# !git clone https://github.com/ultralytics/yolov5
    
# Install requirements specified in the repo
# !pip install -r yolov5/requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 14197, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (73/73), done.
# remote: Total 14197 (delta 83), reused 98 (delta 64), pack-reused 14060
# Receiving objects: 100% (14197/14197), 13.62 MiB | 21.99 MiB/s, done.
# Resolving deltas: 100% (9739/9739), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.5/182.5 kB 4.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# ...

# %%
# Import needed modules
# If you get any errors, install them using the package manager of choice
# Conda is recommended

import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
from PIL import Image
import os

# %%
# Double check that NVIDIA GPU is being used
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 3060

# %%
# Out:
# Using cache found in /home/mdelab/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2022-11-8 Python-3.10.6 torch-1.13.0 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
# ...

# %%
# Train the model!
# !cd yolov5 && python train.py --img 512 --batch 32 --epochs 100 --data data.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=32, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-10-g10c025d Python-3.10.6 torch-1.13.0 CUDA:0 (NVIDIA GeForce RTX 3060, 12053MiB)
#
# ...

# %%
# Train the model! (Rectangular and with RAM caching)
#!cd yolov5 && python train.py --img 960 --batch 16 --epochs 100 --data dataset.yml --weights yolov5m6.pt --rect --cache ram
# Out:
# train: weights=yolov5m6.pt, cfg=, data=dataset.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=960, rect=True, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 8 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.2-231-g0039870 Python-3.10.6 torch-1.13.0 CUDA:0 (NVIDIA GeForce RTX 3060, 12047MiB)
#
# ...
